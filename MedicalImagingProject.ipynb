# %% [markdown]
# <a href="https://colab.research.google.com/github/claredavies/DataEngAPITesting/blob/master/MedicalImagingProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install neeeded packages (After running **RESTART RUNTIME**)

# %%
# !pip install pydicom
# !pip install pylibjpeg
# !pip install gdcm
# !pip install pydicom[pylibjpeg]
# !pip install python-gdcm
# !pip install -U pylibjpeg pylibjpeg-openjpeg pylibjpeg-libjpeg
# !pip install pydicom pylibjpeg pylibjpeg-libjpeg
# !pip install utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.1 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pylibjpeg
#   Downloading pylibjpeg-1.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pylibjpeg) (1.22.4)
# Installing collected packages: pylibjpeg
# Successfully installed pylibjpeg-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gdcm
#   Downloading gdcm-1.1-py3-none-manylinux1_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.9 MB/s eta 0:00:00
# Installing collected packages: gdcm
# Successfully installed gdcm-1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom[pylibjpeg] in /usr/local/lib/python3.10/dist-packages (2.3.1)
# WARNING: pydicom 2.3.1 does not provide the extra 'pylibjpeg'
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-gdcm
#   Downloading python_gdcm-3.0.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: python-gdcm
# Successfully installed python-gdcm-3.0.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pylibjpeg in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Collecting pylibjpeg-openjpeg
#   Downloading pylibjpeg_openjpeg-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.1 MB/s eta 0:00:00
# Collecting pylibjpeg-libjpeg
#   Downloading pylibjpeg_libjpeg-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 47.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pylibjpeg) (1.22.4)
# Installing collected packages: pylibjpeg-openjpeg, pylibjpeg-libjpeg
# Successfully installed pylibjpeg-libjpeg-1.3.4 pylibjpeg-openjpeg-1.3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: pylibjpeg in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: pylibjpeg-libjpeg in /usr/local/lib/python3.10/dist-packages (1.3.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pylibjpeg) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %% [markdown]
# # Loading need libraries

# %%
import os

import matplotlib
import pydicom
import numpy as np
import scipy
from matplotlib import pyplot as plt, animation
import zipfile
import cv2
from scipy.optimize import minimize

# %% [markdown]
# # Tutorial

# %%
def median_sagittal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the median sagittal plane of the CT image provided. """
    return img_dcm[:, :, img_dcm.shape[1]//2]    # Why //2?


def median_coronal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the median sagittal plane of the CT image provided. """
    return img_dcm[:, img_dcm.shape[2]//2, :]


def MIP_sagittal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the maximum intensity projection on the sagittal orientation. """
    return np.max(img_dcm, axis=2)


def AIP_sagittal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the average intensity projection on the sagittal orientation. """
    return np.mean(img_dcm, axis=2)


def MIP_coronal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the maximum intensity projection on the coronal orientation. """
    return np.max(img_dcm, axis=1)


def AIP_coronal_plane(img_dcm: np.ndarray) -> np.ndarray:
    """ Compute the average intensity projection on the coronal orientation. """
    return np.mean(img_dcm, axis=1)


def rotate_on_axial_plane(img_dcm: np.ndarray, angle_in_degrees: float) -> np.ndarray:
    """ Rotate the image on the axial plane. """
    return scipy.ndimage.rotate(img_dcm, angle_in_degrees, axes=(1, 2), reshape=False)

# %% [markdown]
# How do you know the pixel_len_mm???

# %%
dcm = pydicom.dcmread('1-1.dcm')     # Load DICOM file
print(dcm)                          # Print DICOM headers
pixel_len_mm = [3.27, 0.98, 0.98]   # Pixel length in mm [z, y, x]
img_dcm = dcm.pixel_array           # Get pixel array
img_dcm = np.flip(img_dcm, axis=0)  # Change orientation (better visualization)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 198
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Segmentation Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7230010.3.1.4.8323329.773.1600928601.639562
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Segmentation Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.773.1600928601.639562
# (0008, 0020) Study Date                          DA: '19971006'
# (0008, 0021) Series Date                         DA: ''
# (0008, 0023) Content Date                        DA: '20200924'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: '022322'
# (0008, 0033) Content Time                        TM: '022321'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'SEG'
# (0008, 0070) Manufacturer                        LO: 'QIICR'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'LIVER/PELVIS'
# (0008, 103e) Series Description                  LO: 'Segmentation'
# (0008, 1090) Manufacturer's Model Name           LO: 'git@github.com:QIICR/dcmqi.git'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 114a)  Referenced Instance Sequence  79 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.286427832620110275365636763328
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.334394136484584211705832408555
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.108189840982756277041607244378
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.119233713917499526716292243408
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.153982407113481302905934117377
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.334594688104091357853135466531
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.270364089894210813024235771112
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.173723249966037971625680259577
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.565699366733228197586594008653
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.889349412214448465490549572207
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.251986792951701251900070635630
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.113158287608698431800817022164
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.142752564242178059674543216428
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.290015938305989469019850409894
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.376260063329641119203049555178
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.140535170664077179325045970816
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.164865520065009680016566002048
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.515635008284609318995591147128
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.209540834090085916901689163592
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.338330919440066911193022006492
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.105711986280757153328354902582
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.699987617461473256792172665365
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.216994011503051443631695802979
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.243850460192029499253564158299
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.214870323274198827815963050976
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.203333105798951099850761022028
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.966931231944594503671611060568
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.547453480315170932909015382037
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.176473369364372976161793184831
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.259571263179221309205747607193
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.243155739191370997458991246747
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.325522307906289220580868823865
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.293226052319093757718970374384
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.247826177382064467954451618785
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.131942701078676125523929292319
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.138293123954472831591546294099
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.231922138623624645655513857082
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.233579640417810709164709383642
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.213690296468188504242597563336
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.463058949526707339629580152184
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.229577136399497201092016071013
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.896814473180910020542190859270
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.750560747820586446198017124539
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.191496337881204602221085706655
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.234363873772794371018447420971
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.280294249261329062307979871883
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.185083266758364285386960431315
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.151306045275408646676772007131
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.160454758852945220016653853275
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.119641731904729485747510997656
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.316379084670170486325604495308
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.307848447131963579566930972698
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.521097399327737617688354967143
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.273936081440252041983607334786
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.339430184009170470810491776226
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.586882435314094562757572427649
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.187405887321403966664574330079
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.680048136523370895946629996242
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.909530659462022876919435326460
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.100895201107241811513346245150
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.284344833837252164521402167923
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.217679580114489025032523896714
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.632054685363313354288829294472
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.190509519086401391244087335479
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.199846186009340281349828146374
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.332088243899593114999615241983
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.932982104993717530330176125490
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.223739776753854830160876172018
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.763594172775297350930776363097
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.967526235614138269682862978081
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.140248270885046158258039692965
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.186128327723905222836958226060
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.184681227605656836506247900979
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.119190163114274041402943196967
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.970843171112335714498764457418
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.270747523364685768844468159361
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.243701819231314075211677003676
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.130526899192023926675905352159
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.280934465721300685304292318665
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.285388762605622963541285440661
#    ---------
# (0010, 0010) Patient's Name                      PN: 'HCC_004'
# (0010, 0020) Patient ID                          LO: 'HCC_004'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0050) Clinical Trial Time Point ID        LO: '1'
# (0012, 0052) Longitudinal Temporal Offset from E FD: 1.0
# (0012, 0060) Clinical Trial Coordinating Center  LO: 'dcmqi'
# (0012, 0071) Clinical Trial Series ID            LO: 'Session1'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'HCC-TACE-Seg'
# (0013, 1013) Private tag data                    LO: '17068374'
# (0018, 0015) Body Part Examined                  CS: 'LIVER'
# (0018, 1000) Device Serial Number                LO: '0'
# (0018, 1020) Software Versions                   LO: '3efde87'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.643249677828306008300337414785
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.773.1600928601.639561
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '300'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.187477533477078956158186134799
# (0020, 1040) Position Reference Indicator        LO: 'XY'
# (0020, 9221)  Dimension Organization Sequence  1 item(s) ----
#    (0020, 9164) Dimension Organization UID          UI: 1.3.6.1.4.1.43046.3.8323329.773.1600928601.639563
#    ---------
# (0020, 9222)  Dimension Index Sequence  2 item(s) ----
#    (0020, 9164) Dimension Organization UID          UI: 1.3.6.1.4.1.43046.3.8323329.773.1600928601.639563
#    (0020, 9165) Dimension Index Pointer             AT: (0062, 000b)
#    (0020, 9167) Functional Group Pointer            AT: (0062, 000a)
#    (0020, 9421) Dimension Description Label         LO: 'ReferencedSegmentNumber'
#    ---------
#    (0020, 9164) Dimension Organization UID          UI: 1.3.6.1.4.1.43046.3.8323329.773.1600928601.639563
#    (0020, 9165) Dimension Index Pointer             AT: (0020, 0032)
#    (0020, 9167) Functional Group Pointer            AT: (0020, 9113)
#    (0020, 9421) Dimension Description Label         LO: 'ImagePositionPatient'
#    ---------
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: '316'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0100) Bits Allocated                      US: 1
# (0028, 0101) Bits Stored                         US: 1
# (0028, 0102) High Bit                            US: 0
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0062, 0001) Segmentation Type                   CS: 'BINARY'
# (0062, 0002)  Segment Sequence  4 item(s) ----
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '123037004'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Anatomical Structure'
#       ---------
#    (0062, 0004) Segment Number                      US: 1
#    (0062, 0005) Segment Label                       LO: 'Liver'
#    (0062, 0006) Segment Description                 ST: 'Liver'
#    (0062, 0008) Segment Algorithm Type              CS: 'SEMIAUTOMATIC'
#    (0062, 0009) Segment Algorithm Name              LO: 'Amira'
#    (0062, 000d) Recommended Display CIELab Value    US: [34886, 53484, 50172]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '10200004'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Liver'
#       ---------
#    ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '49755003'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Morphologically Altered Structure'
#       ---------
#    (0062, 0004) Segment Number                      US: 2
#    (0062, 0005) Segment Label                       LO: 'Mass'
#    (0062, 0006) Segment Description                 ST: 'Tumor'
#    (0062, 0008) Segment Algorithm Type              CS: 'SEMIAUTOMATIC'
#    (0062, 0009) Segment Algorithm Name              LO: 'Amira'
#    (0062, 000d) Recommended Display CIELab Value    US: [57498, 10747, 54274]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '4147007'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Mass'
#       ---------
#    ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '123037004'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Anatomical Structure'
#       ---------
#    (0062, 0004) Segment Number                      US: 3
#    (0062, 0005) Segment Label                       LO: 'Portal vein'
#    (0062, 0006) Segment Description                 ST: 'vessels'
#    (0062, 0008) Segment Algorithm Type              CS: 'SEMIAUTOMATIC'
#    (0062, 0009) Segment Algorithm Name              LO: 'Amira'
#    (0062, 000d) Recommended Display CIELab Value    US: [63660, 27356, 57178]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '32764006'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Portal vein'
#       ---------
#    ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '123037004'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Anatomical Structure'
#       ---------
#    (0062, 0004) Segment Number                      US: 4
#    (0062, 0005) Segment Label                       LO: 'Abdominal aorta'
#    (0062, 0006) Segment Description                 ST: 'aorta'
#    (0062, 0008) Segment Algorithm Type              CS: 'SEMIAUTOMATIC'
#    (0062, 0009) Segment Algorithm Name              LO: 'Amira'
#    (0062, 000d) Recommended Display CIELab Value    US: [59713, 20540, 29263]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '7832008'
#       (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#       (0008, 0104) Code Meaning                        LO: 'Abdominal aorta'
#       ---------
#    ---------
# (0070, 0080) Content Label                       CS: 'DCMQI'
# (0070, 0081) Content Description                 LO: 'DCMQI'
# (0070, 0084) Content Creator's Name              PN: ''
# (5200, 9229)  Shared Functional Groups Sequence  1 item(s) ----
#    (0020, 9116)  Plane Orientation Sequence  1 item(s) ----
#       (0020, 0037) Image Orientation (Patient)         DS: [1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00, 0.000000e+00]
#       ---------
#    (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#       (0018, 0050) Slice Thickness                     DS: '2.5'
#       (0018, 0088) Spacing Between Slices              DS: '2.5'
#       (0028, 0030) Pixel Spacing                       DS: [6.250000e-01, 6.250000e-01]
#       ---------
#    ---------
# (5200, 9230)  Per-frame Functional Groups Sequence  316 item(s) ----
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.286427832620110275365636763328
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 1]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.050000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.334394136484584211705832408555
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 2]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.025000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.108189840982756277041607244378
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 3]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.000000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.119233713917499526716292243408
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 4]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.975000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.153982407113481302905934117377
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 5]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.950000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.334594688104091357853135466531
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 6]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.925000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.270364089894210813024235771112
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 7]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.900000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.173723249966037971625680259577
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 8]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.875000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.565699366733228197586594008653
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 9]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.850000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.889349412214448465490549572207
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 10]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.825000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.251986792951701251900070635630
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 11]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.800000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.113158287608698431800817022164
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 12]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.775000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.142752564242178059674543216428
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 13]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.750000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.290015938305989469019850409894
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 14]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.725000e+02]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
# ...
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 69]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -3.500000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.967526235614138269682862978081
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 70]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -3.250000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.140248270885046158258039692965
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 71]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -3.000000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.186128327723905222836958226060
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 72]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.750000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.184681227605656836506247900979
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 73]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.500000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.119190163114274041402943196967
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 74]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.250000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.970843171112335714498764457418
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 75]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -2.000000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.270747523364685768844468159361
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 76]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.750000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.243701819231314075211677003676
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 77]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.500000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.130526899192023926675905352159
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 78]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.250000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.1706.8374.280934465721300685304292318665
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [4, 79]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-1.780000e+02, -1.600000e+02, -1.000000e+01]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 4
#       ---------
#    ---------
# (7fe0, 0010) Pixel Data                          OB: Array of 10354688 elements

# %%
# Show median planes
fig, ax = plt.subplots(1, 2)
ax[0].imshow(median_sagittal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[0].set_title('Sagittal')
ax[1].imshow(median_coronal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[2])
ax[1].set_title('Coronal')
fig.suptitle('Median planes')
plt.show()

# %%
# Show MIP/AIP/Median planes
fig, ax = plt.subplots(1, 3)
ax[0].imshow(median_sagittal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[0].set_title('Median')
ax[1].imshow(MIP_sagittal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[1].set_title('MIP')
ax[2].imshow(AIP_sagittal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[2].set_title('AIP')
fig.suptitle('Sagittal')
plt.show()

# %%
fig, ax = plt.subplots(1, 3)
ax[0].imshow(median_coronal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[0].set_title('Median')
ax[1].imshow(MIP_coronal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[1].set_title('MIP')
ax[2].imshow(AIP_coronal_plane(img_dcm), cmap=matplotlib.colormaps['bone'], aspect=pixel_len_mm[0]/pixel_len_mm[1])
ax[2].set_title('AIP')
fig.suptitle('Coronal')
plt.show()

# %%
# Create projections varying the angle of rotation
#   Configure visualization colormap
img_min = np.amin(img_dcm)
img_max = np.amax(img_dcm)
cm = matplotlib.colormaps['bone']
fig, ax = plt.subplots()
#   Configure directory to save results
os.makedirs('results/MIP/', exist_ok=True)
#   Create projections
n = 6
projections = []
for idx, alpha in enumerate(np.linspace(0, 360*(n-1)/n, num=n)):
    rotated_img = rotate_on_axial_plane(img_dcm, alpha)
    projection = MIP_sagittal_plane(rotated_img)
    plt.imshow(projection, cmap=cm, vmin=img_min, vmax=img_max, aspect=pixel_len_mm[0] / pixel_len_mm[1])
    plt.savefig(f'results/MIP/Projection_{idx}.png')      # Save animation
    projections.append(projection)  # Save for later animation
# Save and visualize animation
animation_data = [
    [plt.imshow(img, animated=True, cmap=cm, vmin=img_min, vmax=img_max, aspect=pixel_len_mm[0] / pixel_len_mm[1])]
    for img in projections
]
anim = animation.ArtistAnimation(fig, animation_data,
                          interval=250, blit=True)
anim.save('results/MIP/Animation.gif')  # Save animation
plt.show()

# %%
from IPython.display import Image

# Provide the path to the GIF file
gif_path = 'results/MIP/Animation.gif'

# Display the GIF
Image(filename=gif_path)

# %% [markdown]
# # Making sense of headers

# %%
def search_for_header_in_dcm(word_to_search, dcm):
  # Define the word to search for in the header names
  # Search for headers containing the specified word
  matching_headers = []
  for element in dcm:
      if word_to_search.lower() in element.name.lower():
          return True
          matching_headers.append(element.name)

  return False

# %%
def is_single_acquisition_slice(dicom_file):
    if 'AcquisitionNumber' in dicom_file:
        acquisition_number = dicom_file.AcquisitionNumber
        if isinstance(acquisition_number, str):
            acquisition_number = int(acquisition_number)
            
        # Check if the AcquisitionNumber is 1, indicating a single acquisition slice
        if acquisition_number == 1:
            return True

        # if 'SliceIndex' in dicom_file:
        # slice_index = dicom_file.get('SliceIndex', None)
        # if slice_index is None:
        #     return False
        # return slice_index == 1
          
    return False

# %%
def check_index_presence(image_files, segmentation_files):
    list_headers_to_find = ['Slice Index', 'Acquisition Number', 'Per-frame Functional Groups Sequence', 
                            'Image Position Patient', "Segment Identification Sequence", "Referenced Segment Number"]

    found_terms = []
    for dicom_file in image_files + segmentation_files:
        for term in list_headers_to_find:
          res = search_for_header_in_dcm(term, dicom_file)
          if res is True:
            list_headers_to_find.remove(term)
            found_terms.append(term)


    return found_terms

# %%
def load_dicom_segmentation_files(zip_filename, extract_folder):
  # Extract DICOM files from the zip archive
  zip_file_path = zip_filename  

  with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

  image_files = []
  segmentation_files = []
  for root, dirs, files in os.walk(extract_folder):
      for file in files:
          if file.endswith('.dcm'):
              dicom_file = pydicom.dcmread(os.path.join(root, file))
              if is_single_acquisition_slice(dicom_file):
                  image_files.append(dicom_file)
              else:
                  segmentation_files.append(dicom_file)

  return image_files, segmentation_files

# %%
[image_files, segmentation_files] = load_dicom_segmentation_files('Archive.zip','file')

# %%
[image_files, segmentation_files] = load_dicom_segmentation_files('HCC_004.zip')

# %%
print(check_index_presence(image_files, segmentation_files))
# Out:
# ['Acquisition Number', 'Per-frame Functional Groups Sequence']

# %%
def get_header_value(dicom_file, header_name):
    try:
        header_value = dicom_file[header_name].value
    except KeyError:
        header_value = None
    return header_value

# %%
def rearrange_pixel_arrays(image_files, segmentation_files):
     # Retrieve the relevant headers from each DICOM file
    # Retrieve the relevant headers from each DICOM file
     # Retrieve the relevant headers from each DICOM file
    image_headers = [dicom_file.get('AcquisitionNumber', None) for dicom_file in image_files]
    image_position_headers = [dicom_file.get('PerFrameFunctionalGroupsSequence', [{}])[0].get('ImagePositionPatient', None) for dicom_file in image_files]

    # Sort the DICOM files based on the headers
    sorted_image_files = [dicom_file for _, dicom_file in sorted(zip(image_headers, image_files), key=lambda x: x[0])]
    sorted_image_position_headers = [header for _, header in sorted(zip(image_headers, image_position_headers), key=lambda x: x[0])]

    # Create new lists to store the sorted DICOM files and corresponding pixel arrays
    sorted_images = []
    sorted_segmentations = []

    # Iterate through the sorted DICOM files and extract the pixel arrays
    for image_file, image_position_header in zip(sorted_image_files, sorted_image_position_headers):
        image_array = image_file.pixel_array

        # Perform further processing or analysis with the sorted image array

        sorted_images.append(image_array)

    for segmentation_file in segmentation_files:
        segmentation_array = segmentation_file.pixel_array

        # Perform further processing or analysis with the segmentation array

        sorted_segmentations.append(segmentation_array)

    return sorted_images, sorted_segmentations

# %%
[sorted_images, sorted_segmentations] = rearrange_pixel_arrays(image_files, segmentation_files)

# %%
import matplotlib.pyplot as plt

# Display one of the sorted images
plt.imshow(sorted_images[0], cmap='gray')
plt.title('Sorted Image')
plt.show()

# Display one of the sorted segmentations
plt.imshow(sorted_segmentations[0], cmap='jet')
plt.title('Sorted Segmentation')
plt.show()

# %% [markdown]
# # Co-register images

# %%
input_dcm = pydicom.dcmread("AAL3_1mm.dcm")
reference_dcm = pydicom.dcmread('icbm_avg_152_t1_tal_nlin_symmetric_VI.dcm')

# Select a specific slice from the pixel data
input_slice_index = 100  # Adjust this value to the desired slice index
input_slice_data = input_dcm.pixel_array[input_slice_index]

# Select a specific slice from the pixel data
ref_slice_index = 100  # Adjust this value to the desired slice index
ref_slice_data = reference_dcm.pixel_array[ref_slice_index]

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2)

# Display the input slice in the first subplot
axs[0].imshow(input_slice_data, cmap=plt.cm.gray)
axs[0].axis('off')  # Hide the axis ticks
axs[0].set_title('Input Slice')

# Display the reference slice in the second subplot
axs[1].imshow(ref_slice_data, cmap=plt.cm.gray)
axs[1].axis('off')  # Hide the axis ticks
axs[1].set_title('Reference Slice')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the figure
plt.show()

# %%
def detect_landmarks_optical_flow(images):
    # Prepare parameters for Lucas-Kanade optical flow
    lk_params = dict(
        winSize=(15, 15),
        maxLevel=2,
        criteria=(cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03)
    )

    # Initialize empty lists for landmarks
    landmarks = []

    # Convert the first input image to grayscale
    prev_gray = images[0]

    for i in range(1, len(images)):
        # Convert the current input image to grayscale
        curr_gray = images[i]

        # Select a subset of keypoints for tracking
        keypoints_input = cv2.goodFeaturesToTrack(curr_gray, maxCorners=100, qualityLevel=0.3, minDistance=7)

        if keypoints_input is not None:
            # Perform optical flow calculation
            keypoints_reference, status, _ = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray, keypoints_input, None, **lk_params)
            # Filter out unreliable keypoints
            mask = np.zeros_like(images[i])
            good_matches = status.astype(bool)

            for j, (new, old) in enumerate(zip(keypoints_reference, keypoints_input)):
                a, b = new.ravel()
                c, d = old.ravel()
 
                if good_matches[j]:
                    # Store the landmarks
                    landmarks.append([a, b])

        # Set the current grayscale image as the previous image for the next iteration
        prev_gray = curr_gray

    # Convert the landmarks to a NumPy array
    landmarks = np.array(landmarks)

    return landmarks

# %%
def filter_corresponding_landmarks(ref_landmarks, input_landmarks):
    input_landmarks_len = len(input_landmarks)
    ref_landmarks_len = len(ref_landmarks)

    # Find the minimum length between the two sets
    min_length = min(input_landmarks_len, ref_landmarks_len)

    # Slice the landmarks to the size of the smallest set
    input_landmarks = input_landmarks[:min_length]
    ref_landmarks = ref_landmarks[:min_length]

    return input_landmarks, ref_landmarks

# %%
import numpy as np
import cv2
from scipy.optimize import minimize

def coregister_images_landmarks(input_image, reference_image, input_landmarks, reference_landmarks):
    # Convert landmarks to NumPy arrays
    input_landmarks = np.array(input_landmarks)
    reference_landmarks = np.array(reference_landmarks)

    # Define the loss function
    def loss_function(params):
        # Extract translation and rotation parameters
        tx, ty, theta = params

        # Compute the transformation matrix
        transformation_matrix = np.array([[np.cos(theta), -np.sin(theta), tx],
                                          [np.sin(theta), np.cos(theta), ty]])

        # Apply the transformation to the input landmarks
        transformed_input_landmarks = cv2.transform(input_landmarks.reshape(-1, 1, 2), transformation_matrix).reshape(-1, 2)

        # Compute the Euclidean distance between the transformed input landmarks and the reference landmarks
        loss = np.linalg.norm(transformed_input_landmarks - reference_landmarks, axis=1).sum()

        return loss

    # Initialize the initial parameters for optimization
    initial_params = np.array([0, 0, 0])  # Initial translation (tx, ty) and rotation angle (theta)

    # Use an optimizer to find the optimal parameters of the rigid motion
    result = minimize(loss_function, initial_params, method='Nelder-Mead')

    # Retrieve the optimal parameters
    optimal_params = result.x

    # Extract translation and rotation parameters
    tx, ty, theta = optimal_params

    # Compute the transformation matrix
    transformation_matrix = np.array([[np.cos(theta), -np.sin(theta), tx],
                                      [np.sin(theta), np.cos(theta), ty]])

    # Apply the transformation to the input image
    output_image = cv2.warpAffine(input_image, transformation_matrix, (reference_image.shape[1], reference_image.shape[0]))

    return output_image

# %%
def coregistration(input_images, ref_images):
  input_landmarks = detect_landmarks_optical_flow(input_images)
  ref_landmarks = detect_landmarks_optical_flow(ref_images)

  input_landmarks, ref_landmarks = filter_corresponding_landmarks(input_landmarks, ref_landmarks)

  coregistered_image = coregister_images_landmarks(input_images[100],  ref_images[100], input_landmarks, ref_landmarks)
  return coregistered_image

# %%
input_images = input_dcm.pixel_array
ref_images = reference_dcm.pixel_array[0:181]

coregistered_image = (input_images, ref_images)

# Display the reference image
plt.subplot(1, 4, 1)
plt.imshow(ref_images[100], cmap='gray')
plt.title('Reference Image')
plt.axis('off')

# Overlay input image onto reference image
plt.subplot(1, 4, 2)
plt.imshow(input_images[100], cmap='gray')
plt.title('Input Image')
plt.axis('off')

# Overlay input image onto reference image
plt.subplot(1, 4, 3)
plt.imshow(ref_images[100], cmap='gray')
plt.imshow(input_images[100], cmap='cool', alpha=0.5)
plt.title('Input Overlay')
plt.axis('off')

# Coregister the images using landmarks and optimization
coregistered_image = coregister_images_landmarks(input_images[100], ref_images[100], input_landmarks, ref_landmarks)

# Overlay coregistered image onto reference image
plt.subplot(1, 4, 4)
plt.imshow(ref_images[100], cmap='gray')
plt.imshow(coregistered_image, cmap='hot', alpha=0.5)
plt.title('Coregistered Overlay')
plt.axis('off')

plt.tight_layout()  # Adjust the layout for better visualization
plt.show()

# %% [markdown]
# # Detect Thamalas Region

# %%
def threshold_thamalas(im):
  lower_threshold = 100  # Lower threshold value
  upper_threshold = 255  # Upper threshold value

  # Threshold the image
  _, thresholded_image = cv2.threshold(im, lower_threshold, upper_threshold, cv2.THRESH_BINARY)

  return thresholded_image

# %%
def get_image_highlight_thamalas(input_images, ref_images):
  coregistered_image = coregistration(input_images, ref_images)
  coregistered_image_thamalas = threshold_thamalas(coregistered_image)

  # Create a blank 3-channel image with the same dimensions as the grayscale image
  overlay = cv2.cvtColor(ref_images[100], cv2.COLOR_GRAY2BGR)

  # Set the Thalamus region pixels in the overlay image to red
  overlay[coregistered_image_thamalas > 0] = (0, 255, 0)  # BGR value for red

  return overlay

# %%
input_images = input_dcm.pixel_array
ref_images = reference_dcm.pixel_array[0:181]

thamalas_im = get_image_highlight_thamalas(input_images, ref_images)

# Display the reference image
plt.subplot(1, 4, 1)
plt.imshow(ref_images[100], cmap='gray')
plt.title('Reference Image')
plt.axis('off')

# Overlay input image onto reference image
plt.subplot(1, 4, 2)
plt.imshow(input_images[100], cmap='gray')
plt.title('Input Image')
plt.axis('off')

# Overlay input image onto reference image
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(thamalas_im, cv2.COLOR_BGR2RGB))
plt.title('Overlay')
plt.axis('off')

plt.tight_layout()  # Adjust the layout for better visualization
plt.show()
